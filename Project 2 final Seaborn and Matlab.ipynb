# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv")
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
df2=df[['race','time_in_hospital',]]
df2
# Out:
#                    race  time_in_hospital
# 0             Caucasian                 1
# 1             Caucasian                 3
# 2       AfricanAmerican                 2
# 3             Caucasian                 2
# 4             Caucasian                 1
# ...                 ...               ...
# 101761  AfricanAmerican                 3
# 101762  AfricanAmerican                 5
# 101763        Caucasian                 1
# 101764        Caucasian                10
# 101765        Caucasian                 6
#
# [101766 rows x 2 columns]

# %%
sns.barplot(x='race', y='time_in_hospital', data=df2)
# Out:
# <Axes: xlabel='race', ylabel='time_in_hospital'>

# %%
df2
# Out:
#                    race  time_in_hospital
# 0             Caucasian                 1
# 1             Caucasian                 3
# 2       AfricanAmerican                 2
# 3             Caucasian                 2
# 4             Caucasian                 1
# ...                 ...               ...
# 101761  AfricanAmerican                 3
# 101762  AfricanAmerican                 5
# 101763        Caucasian                 1
# 101764        Caucasian                10
# 101765        Caucasian                 6
#
# [101766 rows x 2 columns]

# %%
df2.shape
df2.mean()
# Out:
# <ipython-input-9-39fd65568bab>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.mean()
# time_in_hospital    4.395987
# dtype: float64

# %%
df3=df2.groupby(['race'])['time_in_hospital'].count().sort_values(ascending=False).plot(kind='bar')

# %%
df2.groupby(['race'])['time_in_hospital'].count().sort_values(ascending=False)
# Out:
# race
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: time_in_hospital, dtype: int64

# %%
df2.groupby(['race'])['time_in_hospital'].mean().sort_values(ascending=False)
# Out:
# race
# AfricanAmerican    4.507860
# Caucasian          4.385721
# ?                  4.289485
# Other              4.273572
# Hispanic           4.059892
# Asian              3.995320
# Name: time_in_hospital, dtype: float64

# %%
sns.barplot(x='time_in_hospital', y='race', data=df2)
# Out:
# <Axes: xlabel='time_in_hospital', ylabel='race'>

# %%
df2.groupby(['race'])['time_in_hospital'].count().sort_values(ascending=False).plot(kind='line')
# Out:
# <Axes: xlabel='race'>

# %%
#in this project I wanted to compare the amount of time spent in the hospital according to race. What I found Caucasian were more in number numerical they spent .2 seconds less. What I also learned was that matlib made really cool graphs and visualization not only help capture the summart of the data but made it easier to understand and get straight to the point.
