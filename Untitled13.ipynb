# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv")

# %%
df1=df[["School Name","Regents Exam","Percent Scoring Below 65","Percent Scoring 65 or Above","Percent Scoring 80 or Above"]]

# %%
df1[df1["School Name"]=="P.S. 140 Nathan Straus"]
# Out:
#                    School Name         Regents Exam Percent Scoring Below 65  \
# 3       P.S. 140 Nathan Straus  Common Core Algebra                        s
# 4       P.S. 140 Nathan Straus  Common Core Algebra                        s
# 5       P.S. 140 Nathan Straus   Living Environment                     33.3
# 6       P.S. 140 Nathan Straus   Living Environment                     13.3
# 7       P.S. 140 Nathan Straus   Living Environment                     55.6
# 19482   P.S. 140 Nathan Straus  Common Core Algebra                        s
# 19483   P.S. 140 Nathan Straus  Common Core Algebra                        s
# 19484   P.S. 140 Nathan Straus   Living Environment                        s
# 19485   P.S. 140 Nathan Straus   Living Environment                        s
# 19486   P.S. 140 Nathan Straus   Living Environment                        s
# 19487   P.S. 140 Nathan Straus   Living Environment                        s
# ...

# %%
df_living=df2[df2["Regents Exam"]=="Living Environment"]
# Out:
#                    School Name        Regents Exam Percent Scoring Below 65  \
# 5       P.S. 140 Nathan Straus  Living Environment                     33.3
# 6       P.S. 140 Nathan Straus  Living Environment                     13.3
# 7       P.S. 140 Nathan Straus  Living Environment                     55.6
# 19484   P.S. 140 Nathan Straus  Living Environment                        s
# 19485   P.S. 140 Nathan Straus  Living Environment                        s
# 19486   P.S. 140 Nathan Straus  Living Environment                        s
# 19487   P.S. 140 Nathan Straus  Living Environment                        s
# 19488   P.S. 140 Nathan Straus  Living Environment                     55.6
# 54243   P.S. 140 Nathan Straus  Living Environment                        s
# 54244   P.S. 140 Nathan Straus  Living Environment                        s
# 54245   P.S. 140 Nathan Straus  Living Environment                        s
# ...

# %%
df_living["Percent Scoring Below 65"].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 3            s
# 4            s
# 5         33.3
# 6         13.3
# 7         55.6
# 19482        s
# 19483        s
# 19484        s
# 19485        s
# 19486        s
# 19487        s
# 19488     55.6
# 54241        s
# 54242        s
# 54243        s
# 54244        s
# 54245        s
# 54246        s
# 54247        s
# 54248     33.3
# 54249        s
# 102885       s
# 102886       s
# 102887       s
# 102888       s
# 102889       s
# 102890       s
# 102891       s
# 102892       s
# 102893       s
# 102894       s
# 139893       s
# 139894       s
# 139895       s
# 139896       s
# 139897       s
# 139898       s
# 139899       s
# 139900       s
# 139901       0
# 139902    55.6
# Name: Percent Scoring Below 65, dtype: object>
